# %% [markdown]
# <a href="https://colab.research.google.com/github/groda/Example-Sketches/blob/master/MapReduce_Primer_HelloWorld_bash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://github.com/groda/big_data"><div><img src="https://github.com/groda/big_data/blob/master/logo_bdb.png?raw=true" align=right width="90"></div></a>
#
# # MapReduce: A Primer with <code>Hello World!</code> in bash
# <br>
# <br>
#
# This tutorial serves as a companion to [MapReduce_Primer_HelloWorld.ipynb](https://github.com/groda/big_data/blob/master/MapReduce_Primer_HelloWorld.ipynb), with the implementation carried out in the Bash scripting language requiring only a few lines of code.
#
# For this tutorial, we are going to download the core Hadoop distribution and run Hadoop in _local standalone mode_:
#
# > ❝ _By default, Hadoop is configured to run in a non-distributed mode, as a single Java process._ ❞
#
# (see [https://hadoop.apache.org/docs/stable/.../Standalone_Operation](https://hadoop.apache.org/docs/stable/hadoop-project-dist/hadoop-common/SingleCluster.html#Standalone_Operation))
#
# We are going to run a MapReduce job using MapReduce's [streaming application](https://hadoop.apache.org/docs/stable/hadoop-streaming/HadoopStreaming.html#Hadoop_Streaming). This is not to be confused with real-time streaming:
#
# > ❝ _Hadoop streaming is a utility that comes with the Hadoop distribution. The utility allows you to create and run Map/Reduce jobs with any executable or script as the mapper and/or the reducer._ ❞
#
# MapReduce streaming defaults to using [`IdentityMapper`](https://hadoop.apache.org/docs/stable/api/index.html) and [`IdentityReducer`](https://hadoop.apache.org/docs/stable/api/index.html), thus eliminating the need for explicit specification of a mapper or reducer.
#
# Both input and output are standard files since Hadoop's default filesystem is the regular file system, as specified by the `fs.defaultFS` property in [core-default.xml](https://hadoop.apache.org/docs/stable/hadoop-project-dist/hadoop-common/core-default.xml)).

# %%
# %%bash
# #set -x
# HADOOP_URL="https://dlcdn.apache.org/hadoop/common/hadoop-3.3.6/hadoop-3.3.6.tar.gz"
# wget --quiet --no-clobber $HADOOP_URL >/dev/null
# [ ! -d $(basename $HADOOP_URL .tar.gz) ] && tar -xzf $(basename $HADOOP_URL)
# HADOOP_HOME=$(pwd)'/'$(basename $HADOOP_URL .tar.gz)'/bin'
# PATH=$HADOOP_HOME:$PATH
# which java >/dev/null|| apt install -y openjdk-17-jre-headless
# export JAVA_HOME=$(realpath $(which java) | sed 's/\/bin\/java$//')
# echo -e "Hello, World!">hello.txt
# output_dir="output"$(date +"%Y%m%dT%H%M")
# sleep 10
# mapred streaming -input hello.txt -output $output_dir
# ls -lR output*
# cat $output_dir/part-00000
# Out:
# output20260228T1902:
# total 4
# -rw-r--r-- 1 root root 16 Feb 28 19:02 part-00000
# -rw-r--r-- 1 root root  0 Feb 28 19:02 _SUCCESS
# 0	Hello, World!
# 2026-02-28 19:02:19,709 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2026-02-28 19:02:19,965 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2026-02-28 19:02:19,965 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2026-02-28 19:02:19,988 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2026-02-28 19:02:20,278 INFO mapred.FileInputFormat: Total input files to process : 1
# 2026-02-28 19:02:20,310 INFO mapreduce.JobSubmitter: number of splits:1
# 2026-02-28 19:02:20,998 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local741806845_0001
# 2026-02-28 19:02:20,998 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2026-02-28 19:02:21,479 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2026-02-28 19:02:21,485 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 2026-02-28 19:02:21,488 INFO mapreduce.Job: Running job: job_local741806845_0001
# 2026-02-28 19:02:21,493 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapred.FileOutputCommitter
# 2026-02-28 19:02:21,506 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2026-02-28 19:02:21,508 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2026-02-28 19:02:21,600 INFO mapred.LocalJobRunner: Waiting for map tasks
# 2026-02-28 19:02:21,607 INFO mapred.LocalJobRunner: Starting task: attempt_local741806845_0001_m_000000_0
# 2026-02-28 19:02:21,675 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2026-02-28 19:02:21,676 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2026-02-28 19:02:21,722 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2026-02-28 19:02:21,741 INFO mapred.MapTask: Processing split: file:/content/hello.txt:0+14
# 2026-02-28 19:02:21,770 INFO mapred.MapTask: numReduceTasks: 1
# 2026-02-28 19:02:21,988 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2026-02-28 19:02:21,989 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2026-02-28 19:02:21,989 INFO mapred.MapTask: soft limit at 83886080
# 2026-02-28 19:02:21,989 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2026-02-28 19:02:21,989 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2026-02-28 19:02:21,995 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2026-02-28 19:02:22,007 INFO mapred.LocalJobRunner:
# 2026-02-28 19:02:22,007 INFO mapred.MapTask: Starting flush of map output
# 2026-02-28 19:02:22,007 INFO mapred.MapTask: Spilling map output
# 2026-02-28 19:02:22,007 INFO mapred.MapTask: bufstart = 0; bufend = 22; bufvoid = 104857600
# 2026-02-28 19:02:22,007 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26214396(104857584); length = 1/6553600
# 2026-02-28 19:02:22,033 INFO mapred.MapTask: Finished spill 0
# 2026-02-28 19:02:22,068 INFO mapred.Task: Task:attempt_local741806845_0001_m_000000_0 is done. And is in the process of committing
# 2026-02-28 19:02:22,076 INFO mapred.LocalJobRunner: file:/content/hello.txt:0+14
# 2026-02-28 19:02:22,076 INFO mapred.Task: Task 'attempt_local741806845_0001_m_000000_0' done.
# 2026-02-28 19:02:22,095 INFO mapred.Task: Final Counters for attempt_local741806845_0001_m_000000_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=141410
# 		FILE: Number of bytes written=776343
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=1
# 		Map output records=1
# 		Map output bytes=22
# 		Map output materialized bytes=30
# 		Input split bytes=75
# 		Combine input records=0
# 		Spilled Records=1
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=31
# 		Total committed heap usage (bytes)=218103808
# 	File Input Format Counters
# 		Bytes Read=14
# 2026-02-28 19:02:22,095 INFO mapred.LocalJobRunner: Finishing task: attempt_local741806845_0001_m_000000_0
# 2026-02-28 19:02:22,098 INFO mapred.LocalJobRunner: map task executor complete.
# 2026-02-28 19:02:22,107 INFO mapred.LocalJobRunner: Waiting for reduce tasks
# 2026-02-28 19:02:22,108 INFO mapred.LocalJobRunner: Starting task: attempt_local741806845_0001_r_000000_0
# 2026-02-28 19:02:22,132 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2026-02-28 19:02:22,132 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2026-02-28 19:02:22,132 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2026-02-28 19:02:22,141 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@38003c4c
# 2026-02-28 19:02:22,147 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2026-02-28 19:02:22,181 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=2381106432, maxSingleShuffleLimit=595276608, mergeThreshold=1571530368, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2026-02-28 19:02:22,184 INFO reduce.EventFetcher: attempt_local741806845_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2026-02-28 19:02:22,261 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local741806845_0001_m_000000_0 decomp: 26 len: 30 to MEMORY
# 2026-02-28 19:02:22,272 INFO reduce.InMemoryMapOutput: Read 26 bytes from map-output for attempt_local741806845_0001_m_000000_0
# 2026-02-28 19:02:22,276 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 26, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->26
# 2026-02-28 19:02:22,282 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 2026-02-28 19:02:22,283 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2026-02-28 19:02:22,284 INFO reduce.MergeManagerImpl: finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 2026-02-28 19:02:22,294 INFO mapred.Merger: Merging 1 sorted segments
# 2026-02-28 19:02:22,295 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 16 bytes
# 2026-02-28 19:02:22,297 INFO reduce.MergeManagerImpl: Merged 1 segments, 26 bytes to disk to satisfy reduce memory limit
# 2026-02-28 19:02:22,300 INFO reduce.MergeManagerImpl: Merging 1 files, 30 bytes from disk
# 2026-02-28 19:02:22,301 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 2026-02-28 19:02:22,302 INFO mapred.Merger: Merging 1 sorted segments
# 2026-02-28 19:02:22,306 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 16 bytes
# 2026-02-28 19:02:22,306 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2026-02-28 19:02:22,320 INFO mapred.Task: Task:attempt_local741806845_0001_r_000000_0 is done. And is in the process of committing
# 2026-02-28 19:02:22,324 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2026-02-28 19:02:22,324 INFO mapred.Task: Task attempt_local741806845_0001_r_000000_0 is allowed to commit now
# 2026-02-28 19:02:22,327 INFO output.FileOutputCommitter: Saved output of task 'attempt_local741806845_0001_r_000000_0' to file:/content/output20260228T1902
# 2026-02-28 19:02:22,330 INFO mapred.LocalJobRunner: reduce > reduce
# 2026-02-28 19:02:22,330 INFO mapred.Task: Task 'attempt_local741806845_0001_r_000000_0' done.
# 2026-02-28 19:02:22,331 INFO mapred.Task: Final Counters for attempt_local741806845_0001_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=141502
# 		FILE: Number of bytes written=776401
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=1
# 		Reduce shuffle bytes=30
# 		Reduce input records=1
# 		Reduce output records=1
# 		Spilled Records=1
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=218103808
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=28
# 2026-02-28 19:02:22,331 INFO mapred.LocalJobRunner: Finishing task: attempt_local741806845_0001_r_000000_0
# 2026-02-28 19:02:22,333 INFO mapred.LocalJobRunner: reduce task executor complete.
# 2026-02-28 19:02:22,502 INFO mapreduce.Job: Job job_local741806845_0001 running in uber mode : false
# 2026-02-28 19:02:22,504 INFO mapreduce.Job:  map 100% reduce 100%
# 2026-02-28 19:02:22,507 INFO mapreduce.Job: Job job_local741806845_0001 completed successfully
# 2026-02-28 19:02:22,529 INFO mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=282912
# 		FILE: Number of bytes written=1552744
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=1
# 		Map output records=1
# 		Map output bytes=22
# 		Map output materialized bytes=30
# 		Input split bytes=75
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=1
# 		Reduce shuffle bytes=30
# 		Reduce input records=1
# 		Reduce output records=1
# 		Spilled Records=2
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=31
# 		Total committed heap usage (bytes)=436207616
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=14
# 	File Output Format Counters
# 		Bytes Written=28
# 2026-02-28 19:02:22,529 INFO streaming.StreamJob: Output directory: output20260228T1902
